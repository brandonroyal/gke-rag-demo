# %%
# %pip install langchain pgvector psycopg2-binary tiktoken

# %%
import os
from langchain.llms import HuggingFacePipeline
from langchain.llms import HuggingFaceTextGenInference
from langchain.document_loaders import TextLoader
from langchain.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.vectorstores.pgvector import PGVector

# %%
# test our Llama-2 interface with langchain

llm = HuggingFaceTextGenInference(
    inference_server_url="http://34.70.31.13/",
    max_new_tokens=512,
    top_k=10,
    top_p=0.95,
    typical_p=0.95,
    temperature=0.01,
    repetition_penalty=1.03,
)
llm("[INST] You are a garden who has been trained to provide helpful, respectful and honest answers about yourself and garden plants. Always answer as helpfully as possible, while being safe and keep your responses less than 200 words. Is salt good for asparagus?[/INST]")
# Out:
# " Salt can be beneficial for asparagus in small amounts. It helps to enhance the flavor of the asparagus and can also help to prevent the growth of harmful bacteria. However, it's important to note that too much salt can be harmful to asparagus and other plants, so it's best to use it sparingly. Additionally, it's important to ensure that the soil in which the asparagus is growing is well-drained and has a good balance of nutrients, as salt alone is not enough to support healthy growth."

# %%
# Load list of URLs -> kubernetes.io/docs/concepts/
file1 = open('./data/plant-urls.samples.txt', 'r')

loader = WebBaseLoader(file1.read().splitlines())
documents = loader.load()

# %%
# Chunk all the kubernetes concept documents
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
docs = text_splitter.split_documents(documents)

print("%s chunks in %s pages" % (len(docs), len(documents)))
# Out:
# 77 chunks in 2 pages

# %%
docs

# %%
# Load sentence transformer embeddings
model_name = "sentence-transformers/all-mpnet-base-v2"
model_kwargs = {"device":"cpu"} # use {"device":"cuda"} for distributed embeddings

embeddings = HuggingFaceEmbeddings(model_name=model_name, model_kwargs=model_kwargs)

# %%
# Connection string for connecting to Postgres
CONNECTION_STRING = PGVector.connection_string_from_db_params(
    driver=os.environ.get("PGVECTOR_DRIVER", "psycopg2"),
    host=os.environ.get("PGVECTOR_HOST", "localhost"),
    port=int(os.environ.get("PGVECTOR_PORT", "5432")),
    database=os.environ.get("PGVECTOR_DATABASE", "postgres"),
    user=os.environ.get("PGVECTOR_USER", "postgres"),
    password=os.environ.get("PGVECTOR_PASSWORD", "secretpassword"),
)

# %%
COLLECTION_NAME = "plants-3"

db = PGVector.from_documents(
    embedding=embeddings,
    documents=docs,
    collection_name=COLLECTION_NAME,
    connection_string=CONNECTION_STRING,
)

# %%
# A better way with distributed jobs on Kubernetes - Queue Docs
! sh ./queue-documents.sh -f './data/plant-urls.txt' -t plants-2
# Out:
# queuing documents for distributed processing...
# ---
# File Path: ./data/plant-urls.txt
# PubSub Topic: plants-2
# ---
# publishing https://en.wikipedia.org/wiki/Abelia
# messageIds:
# - '9753628720817927'
# publishing https://en.wikipedia.org/wiki/Abroma
# messageIds:
# - '9076825938252472'
# publishing https://en.wikipedia.org/wiki/Abrus
# messageIds:
# - '9753249188562269'
# publishing https://en.wikipedia.org/wiki/Abutilon
# messageIds:
# - '9753904180023155'
# publishing https://en.wikipedia.org/wiki/Acaena
# messageIds:
# - '9077094802799671'
# publishing https://en.wikipedia.org/wiki/Acalypha
# messageIds:
# - '9753527373857721'
# publishing https://en.wikipedia.org/wiki/Acanthaceae
# messageIds:
# - '9077232016620252'
# publishing https://en.wikipedia.org/wiki/Acanthodium
# messageIds:
# - '9753322369762277'
# publishing https://en.wikipedia.org/wiki/Acantholimon
# messageIds:
# - '9753650600481543'
# publishing https://en.wikipedia.org/wiki/Acanthopale
# messageIds:
# - '9077244049949260'
# publishing https://en.wikipedia.org/wiki/Acanthophoenix
# messageIds:
# - '9076887196761299'
# publishing https://en.wikipedia.org/wiki/Acanthus_(plant)
# messageIds:
# - '9753978689521564'
# publishing https://en.wikipedia.org/wiki/Feijoa
# messageIds:
# - '9753745500659165'
# publishing https://en.wikipedia.org/wiki/Achariaceae
# messageIds:
# - '9753777290447649'
# publishing https://en.wikipedia.org/wiki/Achimenes
# messageIds:
# - '9076954479726680'
# publishing https://en.wikipedia.org/wiki/Aciphylla
# messageIds:
# - '9753687074187243'
# publishing https://en.wikipedia.org/wiki/Acmena
# messageIds:
# - '9753697420871048'
# publishing https://en.wikipedia.org/wiki/Acokanthera
# messageIds:
# - '9753642940869197'
# publishing https://en.wikipedia.org/wiki/Acorus
# messageIds:
# - '9753669513487111'
# publishing https://en.wikipedia.org/wiki/Acradenia
# messageIds:
# - '9754101063556515'
# publishing https://en.wikipedia.org/wiki/Acrocomia
# messageIds:
# - '9075611408735573'
# publishing https://en.wikipedia.org/wiki/Adansonia
# messageIds:
# - '9754038977934882'
# publishing https://en.wikipedia.org/wiki/Adenandra
# messageIds:
# - '9753166391459092'
# publishing https://en.wikipedia.org/wiki/Adenanthos
# messageIds:
# - '9077289903539252'
# publishing https://en.wikipedia.org/wiki/Adenia
# messageIds:
# - '9753764747340055'
# publishing https://en.wikipedia.org/wiki/Adenium
# messageIds:
# - '9753687453938786'
# publishing https://en.wikipedia.org/wiki/Adenocarpus
# messageIds:
# - '9754263568631792'
# publishing https://en.wikipedia.org/wiki/Adenophora
# messageIds:
# - '9077097910815477'
# publishing https://en.wikipedia.org/wiki/Adenostoma
# messageIds:
# - '9753264824906286'
# publishing https://en.wikipedia.org/wiki/Adlumia
# messageIds:
# - '9753204249432433'
# publishing https://en.wikipedia.org/wiki/Adonis_(plant)
# messageIds:
# - '9077258185719929'
# publishing https://en.wikipedia.org/wiki/Adromischus
# messageIds:
# - '9753204038687820'
# publishing https://en.wikipedia.org/wiki/Aechmea
# messageIds:
# - '9753283558718384'
# publishing https://en.wikipedia.org/wiki/Aegopodium
# messageIds:
# - '9753978771766070'
# publishing https://en.wikipedia.org/wiki/Aeonium
# messageIds:
# - '9753264615601282'
# publishing https://en.wikipedia.org/wiki/Aeschynanthus
# messageIds:
# - '9076803923586150'
# publishing https://en.wikipedia.org/wiki/Aesculus
# messageIds:
# - '9753267412676577'
# publishing https://en.wikipedia.org/wiki/Aethionema
# messageIds:
# - '9753859244381890'
# publishing https://en.wikipedia.org/wiki/Afgekia
# messageIds:
# - '9077257634616817'
# publishing https://en.wikipedia.org/wiki/Agapanthus
# messageIds:
# - '9753687171123937'
# publishing https://en.wikipedia.org/wiki/Agapetes
# messageIds:
# - '9754061149967321'
# publishing https://en.wikipedia.org/wiki/Agastache
# messageIds:
# - '9077256160388797'
# publishing https://en.wikipedia.org/wiki/Agathis
# messageIds:
# - '9753440719016500'
# publishing https://en.wikipedia.org/wiki/Agathosma
# messageIds:
# - '9753577542022237'
# publishing https://en.wikipedia.org/wiki/Agave
# messageIds:
# - '9077085856048400'
# publishing https://en.wikipedia.org/wiki/Ageratum
# messageIds:
# - '9753728488171848'
# publishing https://en.wikipedia.org/wiki/Aglaia
# messageIds:
# - '9753764747439868'
# publishing https://en.wikipedia.org/wiki/Aglaomorpha_(plant)
# messageIds:
# - '9076849965055891'
# publishing https://en.wikipedia.org/wiki/Aglaonema
# messageIds:
# - '9753527830175805'
# publishing https://en.wikipedia.org/wiki/Agonis
# messageIds:
# - '9077548271398574'
# publishing https://en.wikipedia.org/wiki/Agrimonia
# messageIds:
# - '9077111917478818'
# publishing https://en.wikipedia.org/wiki/Agrostis
# messageIds:
# - '9077072325937856'
# publishing https://en.wikipedia.org/wiki/Aichryson
# messageIds:
# - '9076890321300007'
# publishing https://en.wikipedia.org/wiki/Aiphanes
# messageIds:
# - '9753217488469833'
# publishing https://en.wikipedia.org/wiki/Ajania
# messageIds:
# - '9753672206099908'
# publishing https://en.wikipedia.org/wiki/Akebia
# messageIds:
# - '9753788821603755'
# publishing https://en.wikipedia.org/wiki/Alangium
# messageIds:
# - '9753217961793454'
# publishing https://en.wikipedia.org/wiki/Rubiaceae
# messageIds:
# - '9754045085321578'
# publishing https://en.wikipedia.org/wiki/Albuca
# messageIds:
# - '9753306121664287'
# publishing https://en.wikipedia.org/wiki/Alchemilla
# messageIds:
# - '9753278803002343'
# publishing https://en.wikipedia.org/wiki/Aldrovanda
# messageIds:
# - '9753849451311836'
# publishing https://en.wikipedia.org/wiki/Aleurites
# messageIds:
# - '9750655554488755'
# publishing https://en.wikipedia.org/wiki/Alkanna
# messageIds:
# - '9753654408417137'
# publishing https://en.wikipedia.org/wiki/Allagoptera
# messageIds:
# - '9077362301729004'
# publishing https://en.wikipedia.org/wiki/Allamanda
# messageIds:
# - '9753639438360581'
# publishing https://en.wikipedia.org/wiki/Allocasuarina
# messageIds:
# - '9753746315447904'
# publishing https://en.wikipedia.org/wiki/Allosyncarpia
# messageIds:
# - '9750523568293070'
# publishing https://en.wikipedia.org/wiki/Alloxylon
# messageIds:
# - '9076793599544385'
# publishing https://en.wikipedia.org/wiki/Alluaudia
# messageIds:
# - '9753203631674799'
# publishing https://en.wikipedia.org/wiki/Alocasia
# messageIds:
# - '9753389805078909'
# publishing https://en.wikipedia.org/wiki/Aloe
# messageIds:
# - '9749834653973048'
# publishing https://en.wikipedia.org/wiki/Aloinopsis
# messageIds:
# - '9753855612291864'
# publishing https://en.wikipedia.org/wiki/Alonsoa
# messageIds:
# - '9077042713327398'
# publishing https://en.wikipedia.org/wiki/Aloysia
# messageIds:
# - '9753439385850677'
# publishing https://en.wikipedia.org/wiki/Alphitonia
# messageIds:
# - '9753698275810828'
# publishing https://en.wikipedia.org/wiki/Alsobia
# messageIds:
# - '9753895940847464'
# publishing https://en.wikipedia.org/wiki/Alstonia
# messageIds:
# - '9077089668427649'
# publishing https://en.wikipedia.org/wiki/Alstroemeria
# messageIds:
# - '9750400770666520'
# publishing https://en.wikipedia.org/wiki/Alternanthera
# messageIds:
# - '9754039924942710'
# publishing https://en.wikipedia.org/wiki/Althaea_(plant)
# messageIds:
# - '9753751400818764'
# publishing https://en.wikipedia.org/wiki/Alyogyne
# messageIds:
# - '9753166134106704'
# publishing https://en.wikipedia.org/wiki/Alyssum
# messageIds:
# - '9753515985032456'
# publishing https://en.wikipedia.org/wiki/Alyxia
# messageIds:
# - '9751144088721315'
# publishing https://en.wikipedia.org/wiki/Amaranthus
# messageIds:
# - '9753379120145939'
# publishing https://en.wikipedia.org/wiki/Amaryllis
# messageIds:
# - '9753303058807981'
# publishing https://en.wikipedia.org/wiki/Amberboa
# messageIds:
# - '9753639407788053'
# publishing https://en.wikipedia.org/wiki/Amelanchier
# messageIds:
# - '9753777793010909'
# publishing https://en.wikipedia.org/wiki/Amesiella
# messageIds:
# - '9753604828981853'
# publishing https://en.wikipedia.org/wiki/Amherstia
# messageIds:
# - '9753089479495809'
# publishing https://en.wikipedia.org/wiki/Amicia
# messageIds:
# - '9753437017854543'
# publishing https://en.wikipedia.org/wiki/Ammi_(plant)
# messageIds:
# - '9077021275870225'
# publishing https://en.wikipedia.org/wiki/Ammobium
# messageIds:
# - '9751352220178633'
# publishing https://en.wikipedia.org/wiki/Amorpha
# messageIds:
# - '9753854206210828'
# publishing https://en.wikipedia.org/wiki/Amorphophallus
# messageIds:
# - '9753691903817518'
# publishing https://en.wikipedia.org/wiki/Ampelopsis
# messageIds:
# - '9753703711505639'
# publishing https://en.wikipedia.org/wiki/Amsonia
# messageIds:
# - '9076033464137693'
# publishing https://en.wikipedia.org/wiki/Anacampseros
# messageIds:
# - '9753834629810127'
# publishing https://en.wikipedia.org/wiki/Anacardium
# messageIds:
# - '9753352171313211'
# publishing https://en.wikipedia.org/wiki/Anacyclus
# messageIds:
# - '9076493466991737'
# publishing https://en.wikipedia.org/wiki/Anaphalis
# messageIds:
# - '9754053499111694'
# publishing https://en.wikipedia.org/wiki/Anchusa
# messageIds:
# - '9753522700719716'
# publishing https://en.wikipedia.org/wiki/Andersonia_(plant)
# messageIds:
# - '9077046799070147'
# publishing https://en.wikipedia.org/wiki/Andira
# messageIds:
# - '9077253310244988'
# publishing https://en.wikipedia.org/wiki/Androlepis
# messageIds:
# - '9753704763673773'
# publishing https://en.wikipedia.org/wiki/Andromeda_(plant)
# messageIds:
# - '9076828891054624'
# publishing https://en.wikipedia.org/wiki/Andropogon
# messageIds:
# - '9750174393357368'
# publishing https://en.wikipedia.org/wiki/Androsace
# messageIds:
# - '9753816260621580'
# publishing https://en.wikipedia.org/wiki/Anemonella
# messageIds:
# - '9753578715571307'
# publishing https://en.wikipedia.org/wiki/Anemonopsis
# messageIds:
# - '9753672910856357'
# publishing https://en.wikipedia.org/wiki/Anemopaegma
# messageIds:
# - '9753283852950263'
# publishing https://en.wikipedia.org/wiki/Angelica
# messageIds:
# - '9077267754920892'
# publishing https://en.wikipedia.org/wiki/Angelonia
# messageIds:
# - '9750765536624871'
# publishing https://en.wikipedia.org/wiki/Angiopteris
# messageIds:
# - '9753746307798056'
# publishing https://en.wikipedia.org/wiki/Angophora
# messageIds:
# - '9753379188516254'
# publishing https://en.wikipedia.org/wiki/Anigozanthos
# messageIds:
# - '9753950047697777'
# publishing https://en.wikipedia.org/wiki/Anisacanthus
# messageIds:
# - '9753370367715984'
# publishing https://en.wikipedia.org/wiki/Anisodontea
# messageIds:
# - '9075543972769844'
# publishing https://en.wikipedia.org/wiki/Annona
# messageIds:
# - '9754263569117835'
# publishing https://en.wikipedia.org/wiki/Anoda
# messageIds:
# - '9753698027019805'
# publishing https://en.wikipedia.org/wiki/Anopterus
# messageIds:
# - '9077028991247432'
# publishing https://en.wikipedia.org/wiki/Anredera
# messageIds:
# - '9753408666062724'
# publishing https://en.wikipedia.org/wiki/Antennaria
# messageIds:
# - '9075303090333976'
# publishing https://en.wikipedia.org/wiki/Anthemis
# messageIds:
# - '9754229978569519'
# publishing https://en.wikipedia.org/wiki/Anthericum
# messageIds:
# - '9753744273196848'
# publishing https://en.wikipedia.org/wiki/Anthocleista
# messageIds:
# - '9750262745868200'
# publishing https://en.wikipedia.org/wiki/Anthotroche
# messageIds:
# - '9753425923916460'
# publishing https://en.wikipedia.org/wiki/Anthriscus
# messageIds:
# - '9753741668833724'
# publishing https://en.wikipedia.org/wiki/Anthurium
# messageIds:
# - '9077241315890595'
# publishing https://en.wikipedia.org/wiki/Anthyllis
# messageIds:
# - '9750303878138278'
# publishing https://en.wikipedia.org/wiki/Antidesma
# messageIds:
# - '9754083927451669'
# publishing https://en.wikipedia.org/wiki/Antigonon
# messageIds:
# - '9753956152288034'
# publishing https://en.wikipedia.org/wiki/Apera
# messageIds:
# - '9753811110828068'
# publishing https://en.wikipedia.org/wiki/Aphelandra
# messageIds:
# - '9750691365872774'
# publishing https://en.wikipedia.org/wiki/Aphyllanthes
# messageIds:
# - '9753618571452428'
# publishing https://en.wikipedia.org/wiki/Apium
# messageIds:
# - '9077206693280847'
# publishing https://en.wikipedia.org/wiki/Apocynum
# messageIds:
# - '9077247916670350'
# publishing https://en.wikipedia.org/wiki/Aponogeton
# messageIds:
# - '9754055534219329'
# publishing https://en.wikipedia.org/wiki/Apophyllum
# messageIds:
# - '9754083927512299'
# publishing https://en.wikipedia.org/wiki/Apodytes
# messageIds:
# - '9077369278514128'
# publishing https://en.wikipedia.org/wiki/Aporocactus
# messageIds:
# - '9750836066375995'
# publishing https://en.wikipedia.org/wiki/Aprevalia
# messageIds:
# - '9753388959836226'
# publishing https://en.wikipedia.org/wiki/Aptenia
# messageIds:
# - '9076828439079922'
# publishing https://en.wikipedia.org/wiki/Arachis
# messageIds:
# - '9750412706253997'
# publishing https://en.wikipedia.org/wiki/Arachniodes
# messageIds:
# - '9753872540825625'
# publishing https://en.wikipedia.org/wiki/Araeococcus
# messageIds:
# - '9753704913166404'
# publishing https://en.wikipedia.org/wiki/Araiostegia
# messageIds:
# - '9753728267214206'
# publishing https://en.wikipedia.org/wiki/Aralia
# messageIds:
# - '9754013382886981'
# publishing https://en.wikipedia.org/wiki/Araujia
# messageIds:
# - '9753399591299779'
# publishing https://en.wikipedia.org/wiki/Archidendron
# messageIds:
# - '9753973564604710'
# publishing https://en.wikipedia.org/wiki/Arctium
# messageIds:
# - '9077107187747186'
# publishing https://en.wikipedia.org/wiki/Arctotheca
# messageIds:
# - '9753267303692776'
# publishing https://en.wikipedia.org/wiki/Ardisia
# messageIds:
# - '9753729148005997'
# publishing https://en.wikipedia.org/wiki/Areca
# messageIds:
# - '9751531037203162'
# publishing https://en.wikipedia.org/wiki/Arenga
# messageIds:
# - '9754025669983297'
# publishing https://en.wikipedia.org/wiki/Argyranthemum
# messageIds:
# - '9753654657008441'
# publishing https://en.wikipedia.org/wiki/Argyreia
# messageIds:
# - '9753410475152628'
# publishing https://en.wikipedia.org/wiki/Argyroderma
# messageIds:
# - '9075983352972161'
# publishing https://en.wikipedia.org/wiki/Ariocarpus
# messageIds:
# - '9753704735141938'
# publishing https://en.wikipedia.org/wiki/Arisaema
# messageIds:
# - '9753388053047866'
# publishing https://en.wikipedia.org/wiki/Arisarum
# messageIds:
# - '9753715115265981'
# publishing https://en.wikipedia.org/wiki/Aristea
# messageIds:
# - '9077130793532689'
# publishing https://en.wikipedia.org/wiki/Aristolochia
# messageIds:
# - '9752947427550251'
# publishing https://en.wikipedia.org/wiki/Aristotelia_(plant)
# messageIds:
# - '9751158325132049'
# publishing https://en.wikipedia.org/wiki/Armeria
# messageIds:
# - '9753714440915527'
# publishing https://en.wikipedia.org/wiki/Armoracia_armoracia
# messageIds:
# - '9077024243184722'
# publishing https://en.wikipedia.org/wiki/Arnebia
# messageIds:
# - '9077075727788963'
# publishing https://en.wikipedia.org/wiki/Arnica
# messageIds:
# - '9753828464662751'
# publishing https://en.wikipedia.org/wiki/Artanema
# messageIds:
# - '9077077856590928'
# publishing https://en.wikipedia.org/wiki/Artabotrys
# messageIds:
# - '9753872873294974'
# publishing https://en.wikipedia.org/wiki/Arthrocereus
# messageIds:
# - '9751000657249496'
# publishing https://en.wikipedia.org/wiki/Arthropodium
# messageIds:
# - '9077278284737238'
# publishing https://en.wikipedia.org/wiki/Artocarpus
# messageIds:
# - '9077342438599033'
# publishing https://en.wikipedia.org/wiki/Arum
# messageIds:
# - '9753788632356521'
# publishing https://en.wikipedia.org/wiki/Aruncus
# messageIds:
# - '9077100289214297'
# publishing https://en.wikipedia.org/wiki/Arundina
# messageIds:
# - '9753764402569868'
# publishing https://en.wikipedia.org/wiki/Arundinaria
# messageIds:
# - '9753388959970958'
# publishing https://en.wikipedia.org/wiki/Arundo
# messageIds:
# - '9753764323710240'
# publishing https://en.wikipedia.org/wiki/Asarina
# messageIds:
# - '9753641239511903'
# publishing https://en.wikipedia.org/wiki/Asimina
# messageIds:
# - '9753757033758038'
# publishing https://en.wikipedia.org/wiki/Asparagus
# messageIds:
# - '9753465307961626'
# publishing https://en.wikipedia.org/wiki/Asphodeline
# messageIds:
# - '9753289015249468'
# publishing https://en.wikipedia.org/wiki/Aspidistra
# messageIds:
# - '9754060302273913'
# publishing https://en.wikipedia.org/wiki/Asplenium
# messageIds:
# - '9753669471536156'
# publishing https://en.wikipedia.org/wiki/Astelia
# messageIds:
# - '9077025493866405'
# publishing https://en.wikipedia.org/wiki/Aster_(genus)
# messageIds:
# - '9077261897776665'
# publishing https://en.wikipedia.org/wiki/Asteranthera
# messageIds:
# - '9753315571811319'
# publishing https://en.wikipedia.org/wiki/Astilbe
# messageIds:
# - '9753698288895385'
# publishing https://en.wikipedia.org/wiki/Astilboides
# messageIds:
# - '9077161676746118'
# publishing https://en.wikipedia.org/wiki/Astrantia
# messageIds:
# - '9753593894087353'
# publishing https://en.wikipedia.org/wiki/Astrophytum
# messageIds:
# - '9753722865764852'
# publishing https://en.wikipedia.org/wiki/Asystasia
# messageIds:
# - '9076798615135880'
# publishing https://en.wikipedia.org/wiki/Atalaya_(plant)
# messageIds:
# - '9076920881919309'
# publishing https://en.wikipedia.org/wiki/Athamanta
# messageIds:
# - '9753787887058187'
# publishing https://en.wikipedia.org/wiki/Atherosperma
# messageIds:
# - '9077100289323815'
# publishing https://en.wikipedia.org/wiki/Athrotaxis
# messageIds:
# - '9753855402379551'
# publishing https://en.wikipedia.org/wiki/Athyrium
# messageIds:
# - '9754055258803402'
# publishing https://en.wikipedia.org/wiki/Atriplex
# messageIds:
# - '9753948312465448'
# publishing https://en.wikipedia.org/wiki/Attalea_(plant)
# messageIds:
# - '9077410999618996'
# publishing https://en.wikipedia.org/wiki/Aubrieta
# messageIds:
# - '9754101892235620'
# publishing https://en.wikipedia.org/wiki/Aucuba
# messageIds:
# - '9753534488347940'
# publishing https://en.wikipedia.org/wiki/Aulax
# messageIds:
# - '9077017444595415'
# publishing https://en.wikipedia.org/wiki/Auranticarpa
# messageIds:
# - '9750377189576423'
# publishing https://en.wikipedia.org/wiki/Aurinia
# messageIds:
# - '9076961650379935'
# publishing https://en.wikipedia.org/wiki/Austrocedrus
# messageIds:
# - '9752960131000950'
# publishing https://en.wikipedia.org/wiki/Austrocylindropuntia
# messageIds:
# - '9077141294911851'
# publishing https://en.wikipedia.org/wiki/Austrostipa
# messageIds:
# - '9077096756475825'
# publishing https://en.wikipedia.org/wiki/Averrhoa
# messageIds:
# - '9076804593023740'
# publishing https://en.wikipedia.org/wiki/Avicennia
# messageIds:
# - '9753799920652434'
# publishing https://en.wikipedia.org/wiki/Azadirachta
# messageIds:
# - '9076883041891494'
# publishing https://en.wikipedia.org/wiki/Azalea
# messageIds:
# - '9076980059495076'
# publishing https://en.wikipedia.org/wiki/Azara_(plant)
# messageIds:
# - '9753723389104746'
# publishing https://en.wikipedia.org/wiki/Azorella
# messageIds:
# - '9077267296107050'
# publishing https://en.wikipedia.org/wiki/Azorina
# messageIds:
# - '9753879255088098'
# publishing https://en.wikipedia.org/wiki/Aztekium
# messageIds:
# - '9753446974137286'
# publishing https://en.wikipedia.org/w/index.php?title=Azetura&action=edit&redlink=1
# messageIds:
# - '9753815337638506'
# publishing https://en.wikipedia.org/wiki/Babiana
# messageIds:
# - '9753728346901510'
# publishing https://en.wikipedia.org/wiki/Baccharis
# messageIds:
# - '9753473844236290'
# publishing https://en.wikipedia.org/wiki/Backhousia
# messageIds:
# - '9752427552933069'
# publishing https://en.wikipedia.org/wiki/Bactris
# messageIds:
# - '9753741131882657'
# publishing https://en.wikipedia.org/wiki/Baeckea
# messageIds:
# - '9753755869552199'
# publishing https://en.wikipedia.org/wiki/Baikiaea
# messageIds:
# - '9076944071827312'
# publishing https://en.wikipedia.org/wiki/Baileya_(plant)
# messageIds:
# - '9753888768694683'
# publishing https://en.wikipedia.org/wiki/Ballota
# messageIds:
# - '9753741603051691'
# publishing https://en.wikipedia.org/wiki/Banksia
# messageIds:
# - '9753265519826345'
# publishing https://en.wikipedia.org/wiki/Barleria
# messageIds:
# - '9750894948202385'
# publishing https://en.wikipedia.org/wiki/Barnadesia
# messageIds:
# - '9753605221785945'
# publishing https://en.wikipedia.org/wiki/Barringtonia
# messageIds:
# - '9754021594335201'
# publishing https://en.wikipedia.org/wiki/Bartlettina
# messageIds:
# - '9750538735261781'
# publishing https://en.wikipedia.org/wiki/Basselinia
# messageIds:
# - '9753282903898992'
# publishing https://en.wikipedia.org/wiki/Bassia
# messageIds:
# - '9753835408564761'
# publishing https://en.wikipedia.org/wiki/Bauera
# messageIds:
# - '9753630199076644'
# publishing https://en.wikipedia.org/wiki/Bauhinia
# messageIds:
# - '9075704592094174'
# publishing https://en.wikipedia.org/wiki/Baumea
# messageIds:
# - '9753741736447976'
# publishing https://en.wikipedia.org/wiki/Beaucarnea
# messageIds:
# - '9075483326384369'
# publishing https://en.wikipedia.org/wiki/Beaufortia_(plant)
# messageIds:
# - '9077112929569990'
# publishing https://en.wikipedia.org/wiki/Beaumontia
# messageIds:
# - '9077143982597203'
# publishing https://en.wikipedia.org/wiki/Beccariella
# messageIds:
# - '9753894640742251'
# publishing https://en.wikipedia.org/wiki/Bedfordia
# messageIds:
# - '9753797927485812'
# publishing https://en.wikipedia.org/wiki/Begonia
# messageIds:
# - '9077342438905558'
# publishing https://en.wikipedia.org/wiki/Belamcanda
# messageIds:
# - '9753808767979638'
# publishing https://en.wikipedia.org/wiki/Bellevalia
# messageIds:
# - '9753480004947638'
# publishing https://en.wikipedia.org/wiki/Bellium
# messageIds:
# - '9077062748216043'
# publishing https://en.wikipedia.org/wiki/Berberidopsis
# messageIds:
# - '9753316385893479'
# publishing https://en.wikipedia.org/wiki/Berchemia
# messageIds:
# - '9754083726320793'
# publishing https://en.wikipedia.org/wiki/Bergenia
# messageIds:
# - '9753601956410798'
# publishing https://en.wikipedia.org/wiki/Bergerocactus
# messageIds:
# - '9754060509068745'
# publishing https://en.wikipedia.org/wiki/Berkheya
# messageIds:
# - '9753352700910933'
# publishing https://en.wikipedia.org/wiki/Berlandiera
# messageIds:
# - '9754061556750590'
# publishing https://en.wikipedia.org/wiki/Berrya
# messageIds:
# - '9753809507051411'
# publishing https://en.wikipedia.org/wiki/Bertolonia
# messageIds:
# - '9077048675234996'
# publishing https://en.wikipedia.org/wiki/Berzelia
# messageIds:
# - '9753183678538765'
# publishing https://en.wikipedia.org/wiki/Beschorneria
# messageIds:
# - '9753006148030434'
# publishing https://en.wikipedia.org/wiki/Bessera
# messageIds:
# - '9753735194741937'
# publishing https://en.wikipedia.org/wiki/Biarum
# messageIds:
# - '9077102863666972'
# publishing https://en.wikipedia.org/wiki/Bidens
# messageIds:
# - '9753321426405845'
# publishing https://en.wikipedia.org/wiki/Bignonia
# messageIds:
# - '9077094794892785'
# publishing https://en.wikipedia.org/wiki/Bikkia
# messageIds:
# - '9753949997508481'
# publishing https://en.wikipedia.org/wiki/Billardiera
# messageIds:
# - '9077129754392648'
# publishing https://en.wikipedia.org/wiki/Billbergia
# messageIds:
# - '9753904653067890'
# publishing https://en.wikipedia.org/wiki/Bischofia
# messageIds:
# - '9753307098256181'
# publishing https://en.wikipedia.org/wiki/Bismarckia
# messageIds:
# - '9753842898170725'
# publishing https://en.wikipedia.org/wiki/Bixa
# messageIds:
# - '9753828099644685'
# publishing https://en.wikipedia.org/wiki/Blandfordia
# messageIds:
# - '9753528471753408'
# publishing https://en.wikipedia.org/wiki/Blighia
# messageIds:
# - '9753899141670292'
# publishing https://en.wikipedia.org/wiki/Bloomeria
# messageIds:
# - '9753671989614418'
# publishing https://en.wikipedia.org/wiki/Blossfeldia
# messageIds:
# - '9077239638001619'
# publishing https://en.wikipedia.org/wiki/Bocconia_(plant)
# messageIds:
# - '9077142574114122'
# publishing https://en.wikipedia.org/wiki/Boenninghausenia
# messageIds:
# - '9753352261254196'
# publishing https://en.wikipedia.org/wiki/Bolax
# messageIds:
# - '9077255948047154'
# publishing https://en.wikipedia.org/wiki/Bolbitis
# messageIds:
# - '9753816997580846'
# publishing https://en.wikipedia.org/wiki/Boltonia
# messageIds:
# - '9076980059676641'
# publishing https://en.wikipedia.org/wiki/Bolusanthus
# messageIds:
# - '9077369279042905'
# publishing https://en.wikipedia.org/wiki/Bomarea
# messageIds:
# - '9077027652399909'
# publishing https://en.wikipedia.org/wiki/Bombax
# messageIds:
# - '9753343133689397'
# publishing https://en.wikipedia.org/wiki/Bongardia
# messageIds:
# - '9753799560511758'
# publishing https://en.wikipedia.org/wiki/Boophone
# messageIds:
# - '9753209689802267'
# publishing https://en.wikipedia.org/wiki/Borago
# messageIds:
# - '9077047334270357'
# publishing https://en.wikipedia.org/wiki/Borassodendron
# messageIds:
# - '9753306218798748'
# publishing https://en.wikipedia.org/wiki/Borassus
# messageIds:
# - '9077020425604953'
# publishing https://en.wikipedia.org/wiki/Boronia
# messageIds:
# - '9753909803593809'
# publishing https://en.wikipedia.org/wiki/Bosea_(plant)
# messageIds:
# - '9753223729577864'
# publishing https://en.wikipedia.org/wiki/Bossiaea
# messageIds:
# - '9754010450395700'
# publishing https://en.wikipedia.org/wiki/Bothriochloa
# messageIds:
# - '9077169483616326'
# publishing https://en.wikipedia.org/wiki/Bougainvillea
# messageIds:
# - '9077116952671245'
# publishing https://en.wikipedia.org/wiki/Bouteloua
# messageIds:
# - '9753750935925088'
# publishing https://en.wikipedia.org/wiki/Bouvardia
# messageIds:
# - '9753553426000158'
# publishing https://en.wikipedia.org/wiki/Bowenia
# messageIds:
# - '9753728158595270'
# publishing https://en.wikipedia.org/wiki/Bowiea
# messageIds:
# - '9754100988862845'
# publishing https://en.wikipedia.org/wiki/Bowkeria
# messageIds:
# - '9753283336226285'
# publishing https://en.wikipedia.org/wiki/Boykinia
# messageIds:
# - '9753782855629887'
# publishing https://en.wikipedia.org/wiki/Brabejum
# messageIds:
# - '9753264296686561'
# publishing https://en.wikipedia.org/wiki/Brachychiton
# messageIds:
# - '9753815096876260'
# publishing https://en.wikipedia.org/wiki/Brachyglottis
# messageIds:
# - '9753936321140072'
# publishing https://en.wikipedia.org/wiki/Brachylaena
# messageIds:
# - '9753669253250160'
# publishing https://en.wikipedia.org/wiki/Brachypodium
# messageIds:
# - '9753850025252250'
# publishing https://en.wikipedia.org/wiki/Brachyscome
# messageIds:
# - '9753895500761751'
# publishing https://en.wikipedia.org/wiki/Brachysema
# messageIds:
# - '9754026506377395'
# publishing https://en.wikipedia.org/wiki/Brachystelma
# messageIds:
# - '9076924223152857'
# publishing https://en.wikipedia.org/wiki/Bracteantha
# messageIds:
# - '9754065611416527'
# publishing https://en.wikipedia.org/wiki/Breynia
# messageIds:
# - '9753419226271027'
# publishing https://en.wikipedia.org/wiki/Briggsia
# messageIds:
# - '9077239045619406'
# publishing https://en.wikipedia.org/wiki/Brillantaisia
# messageIds:
# - '9077083195905176'
# publishing https://en.wikipedia.org/wiki/Brimeura
# messageIds:
# - '9754092755076937'
# publishing https://en.wikipedia.org/wiki/Brodiaea
# messageIds:
# - '9753793707506961'
# publishing https://en.wikipedia.org/wiki/Bromelia
# messageIds:
# - '9753249198880816'
# publishing https://en.wikipedia.org/wiki/Broussonetia
# messageIds:
# - '9753698663269522'
# publishing https://en.wikipedia.org/wiki/Browallia
# messageIds:
# - '9753783783532549'
# publishing https://en.wikipedia.org/wiki/Brownea
# messageIds:
# - '9077046659873980'
# publishing https://en.wikipedia.org/wiki/Browningia
# messageIds:
# - '9077107782434405'
# publishing https://en.wikipedia.org/wiki/Bruckenthalia
# messageIds:
# - '9753948757110431'
# publishing https://en.wikipedia.org/wiki/Brugmansia
# messageIds:
# - '9753765146834283'
# publishing https://en.wikipedia.org/wiki/Brunfelsia
# messageIds:
# - '9753584841679751'
# publishing https://en.wikipedia.org/wiki/Brunia_(plant)
# messageIds:
# - '9753641448376598'
# publishing https://en.wikipedia.org/wiki/Brunnera
# messageIds:
# - '9753842787815533'
# publishing https://en.wikipedia.org/wiki/Brunsvigia
# messageIds:
# - '9753269863118371'
# publishing https://en.wikipedia.org/wiki/Brya
# messageIds:
# - '9753835013478609'
# publishing https://en.wikipedia.org/wiki/Buchloe_(plant)
# messageIds:
# - '9753879348674969'
# publishing https://en.wikipedia.org/wiki/Buckinghamia
# messageIds:
# - '9075937811333060'
# publishing https://en.wikipedia.org/wiki/Buddleja
# messageIds:
# - '9754004251216031'
# publishing https://en.wikipedia.org/wiki/Buglossoides
# messageIds:
# - '9750364455439205'
# publishing https://en.wikipedia.org/wiki/Bulbine
# messageIds:
# - '9753571342062354'
# publishing https://en.wikipedia.org/wiki/Bulbinella
# messageIds:
# - '9752442248165949'
# publishing https://en.wikipedia.org/wiki/Bulbocodium
# messageIds:
# - '9753811494304625'
# publishing https://en.wikipedia.org/wiki/Bulnesia
# messageIds:
# - '9753745080645032'
# publishing https://en.wikipedia.org/wiki/Bunchosia
# messageIds:
# - '9753769952525222'
# publishing https://en.wikipedia.org/wiki/Buphthalmum
# messageIds:
# - '9753816649647224'
# publishing https://en.wikipedia.org/wiki/Bupleurum
# messageIds:
# - '9750732606273649'
# publishing https://en.wikipedia.org/wiki/Burchardia
# messageIds:
# - '9754064324635830'
# publishing https://en.wikipedia.org/wiki/Burchellia
# messageIds:
# - '9753894906949491'
# publishing https://en.wikipedia.org/wiki/Burretiokentia
# messageIds:
# - '9753322452428583'
# publishing https://en.wikipedia.org/wiki/Bursaria
# messageIds:
# - '9077075030200022'
# publishing https://en.wikipedia.org/wiki/Bursera
# messageIds:
# - '9753850967521913'
# publishing https://en.wikipedia.org/wiki/Burtonia
# ^C
#
#
# Command killed by keyboard interrupt

# %%
# A better way with distributed jobs on Kubernetes
! sh ./deploy-indexer.sh
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# job.batch/indexer-job unchanged
# ---
# waiting for job to start...
# error: timed out waiting for the condition

# %%
query = "Is salt good for asparagus?" # "Should I use gateway API in my app?"
docs = db.similarity_search(query)
print(f"Query: {query}")
print(f"Retrieved documents: {len(docs)}")
for doc in docs:
    doc_details = doc.to_json()['kwargs']
    print("Source: ", doc_details['metadata']['source'])
    print("Text: ", doc_details['page_content'], "\n")
# Out:
# Query: Is salt good for asparagus?
# Retrieved documents: 4
# Source:  https://en.wikipedia.org/wiki/Asparagus
# Text:  Cultivation[edit]
# See also: List of asparagus diseases
# Since asparagus often originates in maritime habitats, it thrives in soils that are too saline for normal weeds to grow. Thus, a little salt was traditionally used to suppress weeds in beds intended for asparagus; this has the disadvantage that the soil cannot be used for anything else. Some places are better for growing asparagus than others. The fertility of the soil is a large factor. "Crowns" are planted in winter, and the first shoots appear in spring; the first pickings or "thinnings" are known as sprue asparagus. Sprue has thin stems.[25]
# A breed of "early-season asparagus" that can be harvested two months earlier than usual was announced by a UK grower in early 2011.[26] This variety does not need to lie dormant and blooms at 7ʡC (45ʡF), rather than the usual 9ʡC (48ʡF).
#
# Source:  https://en.wikipedia.org/wiki/Asparagus
# Text:  Cultivation[edit]
# See also: List of asparagus diseases
# Since asparagus often originates in maritime habitats, it thrives in soils that are too saline for normal weeds to grow. Thus, a little salt was traditionally used to suppress weeds in beds intended for asparagus; this has the disadvantage that the soil cannot be used for anything else. Some places are better for growing asparagus than others. The fertility of the soil is a large factor. "Crowns" are planted in winter, and the first shoots appear in spring; the first pickings or "thinnings" are known as sprue asparagus. Sprue has thin stems.[25]
# A breed of "early-season asparagus" that can be harvested two months earlier than usual was announced by a UK grower in early 2011.[26] This variety does not need to lie dormant and blooms at 7ʡC (45ʡF), rather than the usual 9ʡC (48ʡF).
#
# Source:  https://en.wikipedia.org/wiki/Asparagus
# Text:  Nutrition[edit]
# Water makes up 93% of asparagus's composition.[30] Asparagus is low in food energy and very low in sodium. It is a good source of vitamin B6, calcium, magnesium, and zinc, and a very good source of dietary fibre, protein, beta-carotene, vitamin C, vitamin E, vitamin K, thiamin, riboflavin, rutin, niacin, folic acid, iron, phosphorus, potassium, copper, manganese, and selenium,[31][32] as well as chromium, a trace mineral that regulates the ability of insulin to transport glucose from the bloodstream into cells.[33] The amino acid asparagine gets its name from asparagus, from which it was first isolated, as the asparagus plant is relatively rich in this compound.
#
# Source:  https://en.wikipedia.org/wiki/Asparagus
# Text:  Nutrition[edit]
# Water makes up 93% of asparagus's composition.[30] Asparagus is low in food energy and very low in sodium. It is a good source of vitamin B6, calcium, magnesium, and zinc, and a very good source of dietary fibre, protein, beta-carotene, vitamin C, vitamin E, vitamin K, thiamin, riboflavin, rutin, niacin, folic acid, iron, phosphorus, potassium, copper, manganese, and selenium,[31][32] as well as chromium, a trace mineral that regulates the ability of insulin to transport glucose from the bloodstream into cells.[33] The amino acid asparagine gets its name from asparagus, from which it was first isolated, as the asparagus plant is relatively rich in this compound.

# %%
docs

# %%
from langchain.prompts import PromptTemplate
prompt_template = """[INST] You are a helpful, respectful and honest assistant who is an expert in explaining Kubernetes concepts. Always answer as helpfully as possible, while being safe.
        Use the following pieces of context to answer the question. If you don't know the answer, just say that you don't know, don't try to make up an answer.
        
        {context}

        Question: {question}
        Answer:[/INST]"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

chain_type_kwargs = {"prompt": PROMPT}

# %%
retriever = db.as_retriever()

qa = RetrievalQA.from_chain_type(
    llm=llm, 
    chain_type="stuff", 
    retriever=retriever,
    chain_type_kwargs=chain_type_kwargs,
    verbose=True
)

# %%
result = qa.run("When should I plant asparagus?")
print(result)
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.
#  Asparagus can be planted in the winter, typically in November or December, depending on your location. In colder climates, it's best to plant asparagus crowns, which are the roots of the plant, rather than seedlings. The first shoots will appear in the spring, and the first pickings, known as sprue asparagus, can be harvested in late spring or early summer. It's important to note that asparagus thrives in soils that are too saline for normal weeds to grow, and the fertility of the soil is a large factor. Additionally, some varieties of asparagus can be harvested two months earlier than usual, but this requires careful management and monitoring of the plants.
